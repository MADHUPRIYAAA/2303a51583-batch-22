# %% [markdown]
# <a href="https://colab.research.google.com/github/MADHUPRIYAAA/2303a51583-batch-22/blob/main/lab9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # Import required libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Simulate a Wine Quality dataset
np.random.seed(42)  # For reproducibility
data = pd.DataFrame({
    'fixed_acidity': np.random.uniform(5, 15, 100),
    'volatile_acidity': np.random.uniform(0.1, 1.5, 100),
    'citric_acid': np.random.uniform(0, 1, 100),
    'residual_sugar': np.random.uniform(0.5, 15, 100),
    'alcohol': np.random.uniform(8, 14, 100),
    'quality': np.random.randint(3, 9, 100)  # Wine quality ratings from 3 to 8
})

# Create a pair plot with quality as hue
sns.pairplot(data, vars=['fixed_acidity', 'volatile_acidity', 'citric_acid', 'alcohol'], hue='quality', palette='coolwarm', diag_kind='kde')

# Add title
plt.suptitle("Pair Plot of Wine Chemical Properties vs Quality", y=1.02)

# Display the plot
plt.show()

# %%
# Import required libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Simulate Student Performance dataset
np.random.seed(42)  # For reproducibility
data = pd.DataFrame({
    'study_time': np.random.randint(1, 6, 50),       # Hours per day
    'attendance': np.random.randint(60, 101, 50),    # Attendance percentage
    'exam_score': np.random.randint(50, 101, 50),    # Exam score out of 100
    'gender': np.random.choice(['Male', 'Female'], 50)  # Gender
})

# Create a pair plot with gender as hue
sns.pairplot(data, vars=['study_time', 'attendance', 'exam_score'], hue='gender', palette='Set2', diag_kind='kde')

# Add title
plt.suptitle("Pair Plot of Student Performance Variables", y=1.02)

# Display the plot
plt.show()
